# %% [markdown]
# # Importing all the required libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\Air_Traffic_Passenger_Statistics.csv")
df
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %% [markdown]
# # Performing basic descriptive analysis on the dataset:

# %%
df.sample(5)
# Out:
#        Activity Period                 Operating Airline  \
# 8233            201105  United Airlines - Pre 07/01/2013
# 8165            201105                 American Airlines
# 3922            200804  United Airlines - Pre 07/01/2013
# 10049           201209                  Korean Air Lines
# 2132            200701                Northwest Airlines
#
#       Operating Airline IATA Code                 Published Airline  \
# 8233                           UA  United Airlines - Pre 07/01/2013
# 8165                           AA                 American Airlines
# 3922                           UA  United Airlines - Pre 07/01/2013
# 10049                          KE                  Korean Air Lines
# 2132                           NW                Northwest Airlines
#
#       Published Airline IATA Code    GEO Summary GEO Region  \
# 8233                           UA       Domestic         US
# 8165                           AA       Domestic         US
# ...

# %%
df.head(20)
# Out:
#     Activity Period Operating Airline Operating Airline IATA Code  \
# 0            200507      ATA Airlines                          TZ
# 1            200507      ATA Airlines                          TZ
# 2            200507      ATA Airlines                          TZ
# 3            200507       Air Canada                           AC
# 4            200507       Air Canada                           AC
# 5            200507         Air China                          CA
# 6            200507         Air China                          CA
# 7            200507        Air France                          AF
# 8            200507        Air France                          AF
# 9            200507   Air New Zealand                          NZ
# 10           200507   Air New Zealand                          NZ
# 11           200507   AirTran Airways                          FL
# 12           200507   AirTran Airways                          FL
# ...

# %%
df.tail(30)
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 14977           201603   United Airlines                          UA
# 14978           201603   United Airlines                          UA
# 14979           201603   United Airlines                          UA
# 14980           201603   United Airlines                          UA
# 14981           201603   United Airlines                          UA
# 14982           201603   United Airlines                          UA
# 14983           201603   United Airlines                          UA
# 14984           201603   United Airlines                          UA
# 14985           201603   United Airlines                          UA
# 14986           201603   United Airlines                          UA
# 14987           201603   United Airlines                          UA
# 14988           201603   United Airlines                          UA
# 14989           201603   United Airlines                          UA
# ...

# %%
df.describe()
# Out:
#        Activity Period  Passenger Count  Adjusted Passenger Count  \
# count     15007.000000     15007.000000              15007.000000
# mean     201045.073366     29240.521090              29331.917105
# std         313.336196     58319.509284              58284.182219
# min      200507.000000         1.000000                  1.000000
# 25%      200803.000000      5373.500000               5495.500000
# 50%      201011.000000      9210.000000               9354.000000
# 75%      201308.000000     21158.500000              21182.000000
# max      201603.000000    659837.000000             659837.000000
#
#                Year
# count  15007.000000
# mean    2010.385220
# std        3.137589
# min     2005.000000
# 25%     2008.000000
# 50%     2010.000000
# 75%     2013.000000
# max     2016.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15007 entries, 0 to 15006
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              15007 non-null  int64
#  1   Operating Airline            15007 non-null  object
#  2   Operating Airline IATA Code  14953 non-null  object
#  3   Published Airline            15007 non-null  object
#  4   Published Airline IATA Code  14953 non-null  object
#  5   GEO Summary                  15007 non-null  object
#  6   GEO Region                   15007 non-null  object
#  7   Activity Type Code           15007 non-null  object
#  8   Price Category Code          15007 non-null  object
#  9   Terminal                     15007 non-null  object
#  10  Boarding Area                15007 non-null  object
#  11  Passenger Count              15007 non-null  int64
#  12  Adjusted Activity Type Code  15007 non-null  object
# ...

# %%
df.isnull().any()
# Out:
# Activity Period                False
# Operating Airline              False
# Operating Airline IATA Code     True
# Published Airline              False
# Published Airline IATA Code     True
# GEO Summary                    False
# GEO Region                     False
# Activity Type Code             False
# Price Category Code            False
# Terminal                       False
# Boarding Area                  False
# Passenger Count                False
# Adjusted Activity Type Code    False
# Adjusted Passenger Count       False
# Year                           False
# Month                          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Activity Period                 0
# Operating Airline               0
# Operating Airline IATA Code    54
# Published Airline               0
# Published Airline IATA Code    54
# GEO Summary                     0
# GEO Region                      0
# Activity Type Code              0
# Price Category Code             0
# Terminal                        0
# Boarding Area                   0
# Passenger Count                 0
# Adjusted Activity Type Code     0
# Adjusted Passenger Count        0
# Year                            0
# Month                           0
# dtype: int64

# %% [raw]
# As column 'Operating Airline IATA Code' and 'Published Airline IATA Code' has 54 null values each, adding replacing these values with zeroes.

# %%
df.fillna(0,inplace=True)
print("The new data set without any null value is:")
df
# Out:
# The new data set without any null value is:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
df.isnull().sum()
# Out:
# Activity Period                0
# Operating Airline              0
# Operating Airline IATA Code    0
# Published Airline              0
# Published Airline IATA Code    0
# GEO Summary                    0
# GEO Region                     0
# Activity Type Code             0
# Price Category Code            0
# Terminal                       0
# Boarding Area                  0
# Passenger Count                0
# Adjusted Activity Type Code    0
# Adjusted Passenger Count       0
# Year                           0
# Month                          0
# dtype: int64

# %% [markdown]
# # Finding the frequency of data and its count in each categorical column:
# (Also storing this values in variable so that we can use them in analysis further)

# %%
a = df['Operating Airline'].value_counts()
print(a)
# Out:
# United Airlines - Pre 07/01/2013    2154
# SkyWest Airlines                     963
# United Airlines                      892
# Alaska Airlines                      751
# Delta Air Lines                      386
#                                     ...
# Evergreen International Airlines       2
# Atlas Air, Inc                         2
# Xtra Airways                           2
# Pacific Aviation                       2
# Boeing Company                         1
# Name: Operating Airline, Length: 77, dtype: int64

# %%
df['Operating Airline'].nunique()
# Out:
# 77

# %%
b = df['Published Airline'].value_counts()
print(b)
# Out:
# United Airlines - Pre 07/01/2013    2645
# United Airlines                     1107
# Alaska Airlines                      969
# Delta Air Lines                      803
# American Airlines                    416
#                                     ...
# Evergreen International Airlines       2
# Atlas Air, Inc                         2
# Xtra Airways                           2
# Pacific Aviation                       2
# Boeing Company                         1
# Name: Published Airline, Length: 68, dtype: int64

# %%
df['Operating Airline'].nunique()
# Out:
# 77

# %%
c = df['GEO Summary'].value_counts()
print(c)
# Out:
# International    9210
# Domestic         5797
# Name: GEO Summary, dtype: int64

# %%
d = df['GEO Region'].value_counts()
print(d)
# Out:
# US                     5797
# Asia                   3273
# Europe                 2089
# Canada                 1418
# Mexico                 1115
# Australia / Oceania     737
# Central America         274
# Middle East             214
# South America            90
# Name: GEO Region, dtype: int64

# %%
e = df['Price Category Code'].value_counts()
print(e)
# Out:
# Other       13087
# Low Fare     1920
# Name: Price Category Code, dtype: int64

# %%
f = df['Terminal'].value_counts()
print(f)
# Out:
# International    9197
# Terminal 1       3241
# Terminal 3       2218
# Terminal 2        324
# Other              27
# Name: Terminal, dtype: int64

# %%
g = df['Boarding Area'].value_counts()
print(g)
# Out:
# A        5225
# G        3992
# B        1993
# F        1377
# C        1228
# E         841
# D         324
# Other      27
# Name: Boarding Area, dtype: int64

# %%
h = df['Month'].value_counts()
print(h)
# Out:
# August       1310
# July         1303
# September    1297
# October      1295
# January      1268
# November     1263
# December     1259
# February     1255
# March        1253
# June         1183
# May          1172
# April        1149
# Name: Month, dtype: int64

# %% [markdown]
# # Univariet analysis:

# %% [markdown]
# ***As the total number of airlines operating under the given Air traffic data is 77 (which is quite large), analysing the data of top 15 airlies that are used most frequently by the customers:
# {This is because we are interested in most preffered airlines of the customers}***

# %%
df = df.sort_values(by='Passenger Count', ascending = False)
print("The data frame sorted in decreasing order of passenger count is:")
df
# Out:
# The data frame sorted in decreasing order of passenger count is:
#        Activity Period                 Operating Airline  \
# 11331           201308                   United Airlines
# 11332           201308                   United Airlines
# 11218           201307                   United Airlines
# 11219           201307                   United Airlines
# 11566           201310                   United Airlines
# ...                ...                               ...
# 1865            200611                       Ameriflight
# 4218            200807                       Ameriflight
# 9065            201112  United Airlines - Pre 07/01/2013
# 3501            200801                       Ameriflight
# 13268           201501                   United Airlines
#
#       Operating Airline IATA Code                 Published Airline  \
# 11331                          UA                   United Airlines
# 11332                          UA                   United Airlines
# ...

# %%
plt.figure(figsize = (15,6))
a[:15:].plot(kind='bar', color = ['mediumaquamarine','aquamarine','turquoise','lightseagreen','mediumturquoise','paleturquoise','darkslategrey','teal','darkcyan','c','cyan','darkturquoise','cadetblue','powderblue','lightblue']);
plt.title('Top 15 preffered airlines',fontsize=15,color='steelblue');
plt.ylabel('Number of flights preffereb by the customer of that particular airline',fontsize=10,c='steelblue');
plt.xlabel('Airline company',fontsize=20,c='steelblue');

# %% [raw]
# The graph above shows the top 15 airlines preferred by the customers. Out of which the Uniter Airlines - Pre 07/01/2013 are the most preferred one.

# %%
plt.figure(figsize = (15,6))
b[:15:].plot(kind='bar', color = ['mediumaquamarine','aquamarine','turquoise','lightseagreen','mediumturquoise','paleturquoise','darkslategrey','teal','darkcyan','c','cyan','darkturquoise','cadetblue','powderblue','lightblue']);
plt.title('Top 15 Published airlines',fontsize=15,color='steelblue');
plt.ylabel('Number of flights published by that particular airline',fontsize=13,c='steelblue');
plt.xlabel('Airline company',fontsize=20,c='steelblue');

# %% [raw]
# The above graph shows the top 15 airline companies that published most number of flights amongst the given Air Traffic data.

# %%
plt.figure(figsize=(6,6))
plt.pie(c,labels=['International','Domestic'],autopct='%i%%',colors=['crimson','orange'],explode = [0,0.05])
plt.title('Distrubution of flight types',fontsize=15,color='k');

# %% [raw]
# The above graph reprsents that, in the given air traffic data, there are more number of international flights than the domestic flights.

# %%
plt.figure(figsize = (10,4))
d.plot(kind='bar',color=['y','yellow','olivedrab','yellowgreen','darkolivegreen','greenyellow','chartreuse','lawngreen','palegreen'])
plt.title('Summary of Geo region',fontsize=15,color='k');
plt.ylabel('No of flights in particular GEO reg',fontsize=15,c='darkgreen');
plt.xlabel('GEO region',fontsize=20,c='darkgreen');

# %% [raw]
# From the given air traffic data, we can say that most number of flights flew to the US followed by the Asia and Europe.

# %%
plt.figure(figsize=(6,6))
plt.pie(e,labels=['Other','Low fare'],autopct='%i%%',colors=['rebeccapurple','darkorchid'],explode = [0,0.05])
plt.title('Price category',fontsize=15,color='k');

# %% [raw]
# From the given air traffic data, we can say that the low fare flights contribute 12% of total flights whereas the other category contributes 87%

# %%
plt.figure(figsize=(10,4))
f.plot(kind='bar',color=['darkred','indianred','lightcoral','salmon','mistyrose'])
plt.title('Air traffic at particular terminal',fontsize=15,color='k');
plt.xlabel('Terminals',fontsize=13,color='k');
plt.ylabel('Number of flights',fontsize=13,color='k');

# %%
plt.figure(figsize=(10,6))
plt.pie(g,labels=['A','G','B','F','C','E','D','Others'],autopct='%i%%',colors=['firebrick','orange','green','yellow','mediumvioletred','darkblue','purple','k'])
plt.title('Boarding area data',fontsize=15,color='k');

# %% [raw]
# Above graph shows air traffic at particular boarding area.

# %%
plt.figure(figsize = (15,4))
h.plot(kind='bar', color = ['mediumaquamarine','aquamarine','turquoise','lightseagreen','mediumturquoise','paleturquoise','darkslategrey','teal','darkcyan','c','cyan','darkturquoise']);
plt.title('Monthly distribution of air traffic',fontsize=15,color='k');
plt.ylabel('Number of flights',fontsize=13,c='steelblue');
plt.xlabel('Months',fontsize=13,c='steelblue');

# %% [raw]
# The number of flights that flew in the months of August, July, September and October were almost same and were highest.

# %% [markdown]
# # Bivariet and Multivariet Analysis:

# %% [raw]
# As our dataset has very less amount of numerical data, plotting a pair plot to check if we can get any insight from the numerical data.

# %%
sns.pairplot(data = df);

# %% [raw]
# From the above graphs, we can see that there is a linearly increasing relation between Year and Activity period. From the dataset, we can see that the values of Adjusted Passenger Count and Passenger Count is same. So the graph with this two parameters are also linearly increasing. But this will be considered as a bivariet graph as two different parameters are there.

# %% [raw]
# As we have large number of categories in every variable (coloumn) of our data creating a new data sets (namely df1) to analyse data for only top three airline companies preferred by the customers.

# %%
df1 = df[(df['Operating Airline'] == 'United Airlines - Pre 07/01/2013')| (df['Operating Airline']=='SkyWest Airlines')| (df['Operating Airline']=='United Airlines')]
df1
# Out:
#        Activity Period                 Operating Airline  \
# 11331           201308                   United Airlines
# 11332           201308                   United Airlines
# 11218           201307                   United Airlines
# 11219           201307                   United Airlines
# 11566           201310                   United Airlines
# ...                ...                               ...
# 5242            200903  United Airlines - Pre 07/01/2013
# 13046           201411                   United Airlines
# 13993           201507                   United Airlines
# 9065            201112  United Airlines - Pre 07/01/2013
# 13268           201501                   United Airlines
#
#       Operating Airline IATA Code                 Published Airline  \
# 11331                          UA                   United Airlines
# 11332                          UA                   United Airlines
# 11218                          UA                   United Airlines
# ...

# %%
sns.barplot(data=df1, x='GEO Summary', y='Passenger Count');
plt.title('Comparision of number of flights as per there Geo Summary');

# %% [raw]
# From the above graph, we can say that amongst the most preffered airlines customer has borded domestic flights more than the international flights.

# %%
sns.barplot(data=df1, x='GEO Summary', y='Passenger Count', hue='Operating Airline');
plt.title('Distribution of Passengers as per the Geo Summary and Operating Airlines');

# %% [raw]
# From the above graph we can say that amongst the Domestic flights and Internatinal flights, United Airlines is the most preffered one.

# %%
plt.figure(figsize = (13,6))
sns.barplot(data=df1, x='GEO Region', y='Passenger Count', hue='Operating Airline');
plt.title('Distribution of Passengers as per the Geo Region and Operating Airlines');

# %% [raw]
# The above graph shows us that there are no flights from the SkyWest airlines flying to the Asia, Europe, Mexico and Australia/Oceania region. So for this airline to extend there business, they should concentrate on these area.

# %%
plt.figure(figsize=(15,6))
sns.barplot(data=df1, x='Month', y='Passenger Count', hue='Operating Airline');
plt.title('Distribution of Passengers as per the Geo Summary and Operating Airlines');

# %% [raw]
# The above graph shows the monthwise operating frequency of each operating airline. Also, it helps us to understand the airlines preffered by the customer in a particular month. Analysing this data can help an airline to increase there sale in particular month and hence improve there business.

# %%
sns.barplot(data=df1, x='Terminal', y='Passenger Count', hue='Operating Airline');
plt.title('Graph to analyse crowd on a particular terminal');

# %% [raw]
# The above graph shows that the top 3 preffered airlines have their flights on Terminal 3, Terminal 1 and International Terminal. Out of which Terminal 3 is the most preffered one. We can also conclude that the Internatinal terminal is used very rarely by the SkyWest Airlines.

# %%
plt.figure(figsize = (13,6));
sns.barplot(data=df1, x='Boarding Area', y='Passenger Count', hue='Operating Airline');
plt.title('Graph to analyse crowd in a Boarding Area');

# %% [raw]
# The above graph shows that the boarding area E is not used by the SkyWest Airlines. Similarly boarding area C and A is only used by SkyWest Airlines. At boarding area B, the frequency of flights of United Airlines is less as compared to other two airlines.

# %%
a1 = pd.crosstab(df1['Boarding Area'],df1['Terminal'])
print('The distribution of bording areas as per the Terminal is as follows:')
a1
# Out:
# The distribution of bording areas as per the Terminal is as follows:
# Terminal       International  Terminal 1  Terminal 3
# Boarding Area
# A                          2           0           0
# B                          0         237           0
# C                          0         255           0
# E                          0           0         390
# F                          0           0        1377
# G                       1748           0           0

# %%
a1.plot(kind='bar', stacked=True);

# %%
a2 = pd.crosstab(df1['Boarding Area'],df1['GEO Summary'])
print('The distribution of flight type as per the Boarding area along with its graph is as follows:')
print(a2)
a2.plot(kind='bar', stacked=True);
plt.title('Distrubition of Boarding area used as per Geo Summary')
plt.text(1,197,196,color='k',ha='center')
plt.text(1,60,41,color='k',ha='center')
plt.text(2,90,255,color='k',ha='center')
plt.text(3,342,49,color='k',ha='center')
plt.text(3,130,341,color='k',ha='center')
plt.text(4,500,764,color='k',ha='center')
plt.text(4,1000,613,color='k',ha='center')
plt.text(5,60,244,color='k',ha='center')
plt.text(5,1000,1504,color='k',ha='center')
plt.show()
# Out:
# The distribution of flight type as per the Boarding area along with its graph is as follows:
# GEO Summary    Domestic  International
# Boarding Area
# A                     2              0
# B                   196             41
# C                   255              0
# E                   341             49
# F                   764            613
# G                   244           1504

# %% [raw]
# The graph shows that Boarding area A and C don't have any international flights.

# %%
a3 = pd.crosstab(df1['Boarding Area'],df1['GEO Region'])
print('The distribution of bording areas as per the Geo Region alongwith the graph is as follows:')
print(a3)
a3.plot(kind='bar', stacked=True)
plt.title('Frequecy of Boarding area used as per the Geo Region',fontsize=15, color='firebrick')
plt.text(1,7,41,color='white',ha='center')
plt.text(1,147,196,color='white',ha='center')
plt.text(2,90,255,color='white',ha='center')
plt.text(3,5,35,color='white',ha='center')
#plt.text(3,15,14,color='white',ha='center')
plt.text(3,200,351,color='white',ha='center')
plt.text(4,600,590,color='white',ha='center')
plt.text(4,350,21,color='white',ha='center')
plt.text(4,1000,764,color='white',ha='center')
plt.text(5,1300,336,color='white',ha='center')
plt.text(5,1000,344,color='white',ha='center')
plt.text(5,1600,244,color='white',ha='center')
plt.text(5,150,346,color='white',ha='center')
plt.text(5,450,344,color='white',ha='center')
plt.text(5,750,134,color='white',ha='center')
plt.show()
# Out:
# The distribution of bording areas as per the Geo Region alongwith the graph is as follows:
# GEO Region     Asia  Australia / Oceania  Canada  Europe  Mexico   US
# Boarding Area
# A                 0                    0       0       0       0    2
# B                 0                    0      41       0       0  196
# C                 0                    0       0       0       0  255
# E                 0                    0      35       0      14  341
# F                 2                    0     590       0      21  764
# G               346                  344     134     344     336  244
